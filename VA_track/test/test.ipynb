# %%
path='/data/wenzhuofan/Data/AVEC2013/PreProcessed/Original/label'
import numpy as np
import os

a=np.load(os.path.join(path,'partition_orignal.npz'),allow_pickle=True)
print(a['train'])
# Out:
# {'/data/wenzhuofan/Data/AVEC2013/RAW/train/203_1_03': 3, '/data/wenzhuofan/Data/AVEC2013/RAW/train/205_2_03': 3, '/data/wenzhuofan/Data/AVEC2013/RAW/train/207_2_10': 10, '/data/wenzhuofan/Data/AVEC2013/RAW/train/208_2_04': 4, '/data/wenzhuofan/Data/AVEC2013/RAW/train/209_1_06': 6, '/data/wenzhuofan/Data/AVEC2013/RAW/train/213_1_33': 33, '/data/wenzhuofan/Data/AVEC2013/RAW/train/214_1_11': 11, '/data/wenzhuofan/Data/AVEC2013/RAW/train/215_2_09': 9, '/data/wenzhuofan/Data/AVEC2013/RAW/train/215_3_05': 5, '/data/wenzhuofan/Data/AVEC2013/RAW/train/217_2_30': 30, '/data/wenzhuofan/Data/AVEC2013/RAW/train/217_3_32': 32, '/data/wenzhuofan/Data/AVEC2013/RAW/train/219_1_33': 33, '/data/wenzhuofan/Data/AVEC2013/RAW/train/219_3_19': 19, '/data/wenzhuofan/Data/AVEC2013/RAW/train/223_1_00': 0, '/data/wenzhuofan/Data/AVEC2013/RAW/train/223_2_00': 0, '/data/wenzhuofan/Data/AVEC2013/RAW/train/225_2_15': 15, '/data/wenzhuofan/Data/AVEC2013/RAW/train/226_1_35': 35, '/data/wenzhuofan/Data/AVEC2013/RAW/
# ...

# %%
import config
dataset = 'AVEC2013'
video_path = config.PATH_TO_VIDEO[dataset]
print(video_path)
# Out:
# /data/wenzhuofan/Data/AVEC2013/PreProcessed/Original/video

# %%
a=[[1],[2],[3]]
import numpy as np
a=np.array(a)
a=a.flatten()
print(a)
# Out:
# [1 2 3]
